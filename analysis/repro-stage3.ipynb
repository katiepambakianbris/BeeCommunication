# %%
# Imports

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# load in the results
result_dir = "/Users/katiepambakian/Documents/BSc Computer Science/Y3/Dissertation/BeeCommunication/results/"

# date = "2026-03-12/"
# slurm_job = 16290178 -> exibited the correct behaviour
date = "2026-03-13/"
slurm_job = 16320581
batches = [0, 3, 4, 6, 7, 8, 12, 13, 14, 17, 19]

result_dir = result_dir + date + str(slurm_job) + "/"
# result_dir = "/Users/katiepambakian/Documents/BSc Computer Science/Y3/Dissertation/BeeCommunication/results/2026-03-11/batch_3/run_0"
# result_dir = result_dir + date + "v/"
# result_dir = result_dir + date + "/"

# start at line number 1
def read_ith_line(i, filename):
    with open(filename, "r") as file:
        for line_number, line in enumerate(file, start=1):
            if (line_number == i):
                return [float(x) for x in line.strip().split()]
            
    # If file exists but doesn't have that many lines
    return []

# %%
# training phase + pause behaviour
# this is looking at a single file
# phases = ["Phase1", "Phase2"]

delay = "delay"
envs = [1,2,3]
stage = "stage3"

run = 0

colors = [
    "#1F77B4",  # Blue
    "#FF7F0E",  # Orange
    "#2CA02C",  # Green
    "#D62728",  # Red
    "#9467BD",  # Purple
    "#8C564B",  # Brown
    "#E377C2",  # Pink
    "#7F7F7F",  # Grey
    "#17BECF"   # Teal
]

for batch_index, batch in enumerate(batches):
    for env in envs:
        fig, ax = plt.subplots(figsize=(16,10))
        ax2 = ax.twinx()
        # first plot phase 1 and phase 2 in the same plot
        phase1_dir = result_dir + f"batch_{batch}/run_{run}/behavior_{run}_Env{env}_{stage}_Phase1.dat"
        phase2_dir = result_dir + f"batch_{batch}/run_{run}/behavior_{run}_Env{env}_{stage}_Phase2.dat"
        landmark_file = result_dir+ f"batch_{batch}/run_{run}/landmark_location_{run}_env{env}_{stage}_phase2.dat"
    
        
        for i in range(0, 9):
            behavior = []
            behavior.extend(read_ith_line(1, phase1_dir))
            behavior.extend(read_ith_line(i+1, phase2_dir))
            x = list(range(0, len(behavior)))
            ax.plot(x, behavior, label=f"Agent", color=colors[i])

            landmark = read_ith_line(i+1, landmark_file)
            # print(landmark)
            landmarks = [0,1,2]
            for i in landmarks:
                if (i != env-1):
                    ax.axhline(y=landmark[i], linestyle="--", label=f"Landmark {i}", color="grey")
                else:
                    ax.axhline(y=landmark[i], linestyle="--", label="Food Position", color="green")

        # fitness
        fitness_file = result_dir+ f"batch_{batch}/run_{run}/fitness_{run}_env{env}_{stage}.dat"
        fitness = read_ith_line(1, fitness_file)
        fitness_start = (len(behavior) - len(fitness))
        fitness_x = range(fitness_start, len(fitness)+fitness_start)

        ax2.plot(fitness_x, fitness, linestyle="dashdot", color="purple")
        ax2.set_ylim(bottom=-0.1, top=1.1)
        ax2.set_ylabel("Fitness")
        # plot it
        ax.set_xlabel("Time")
        ax.set_ylabel("Distance from origin")
        ax.set_title(f"Batch {batch}, Env {env} - Stage 3")
        ax.grid(True)
        fig.show()
# Out:
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# /var/folders/fz/htwq5qzj5_d0ry3b14hmlrsw0000gn/T/ipykernel_75878/3932120663.py:63: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# /var/folders/fz/htwq5qzj5_d0ry3b14hmlrsw0000gn/T/ipykernel_75878/3932120663.py:25: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(16,10))
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
# [26.0, 39.0, 52.0, 26.0]
# [28.0, 43.0, 58.0, 28.0]
# [30.0, 47.0, 64.0, 30.0]
# [28.0, 41.0, 54.0, 28.0]
# [30.0, 45.0, 60.0, 30.0]
# [32.0, 49.0, 66.0, 32.0]
# [30.0, 43.0, 56.0, 30.0]
# [32.0, 47.0, 62.0, 32.0]
# [34.0, 51.0, 68.0, 34.0]
# [26.0, 39.0, 52.0, 39.0]
# [28.0, 43.0, 58.0, 43.0]
# [30.0, 47.0, 64.0, 47.0]
# [28.0, 41.0, 54.0, 41.0]
# [30.0, 45.0, 60.0, 45.0]
# [32.0, 49.0, 66.0, 49.0]
# [30.0, 43.0, 56.0, 43.0]
# [32.0, 47.0, 62.0, 47.0]
# [34.0, 51.0, 68.0, 51.0]
# [26.0, 39.0, 52.0, 52.0]
# [28.0, 43.0, 58.0, 58.0]
# [30.0, 47.0, 64.0, 64.0]
# [28.0, 41.0, 54.0, 54.0]
# [30.0, 45.0, 60.0, 60.0]
# [32.0, 49.0, 66.0, 66.0]
# [30.0, 43.0, 56.0, 56.0]
# [32.0, 47.0, 62.0, 62.0]
# [34.0, 51.0, 68.0, 68.0]
